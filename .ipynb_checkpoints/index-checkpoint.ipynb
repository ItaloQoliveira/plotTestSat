# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data.csv")
x = data.AlturaSatelite
y = data.AlturaContainer
plt.title('Altura do satélite por altura de conteiner', color = 'blue', fontsize=18)
plt.ylabel('Altura de conteiner')
plt.xlabel('Altura do satélite')
plt.scatter(x,y)
